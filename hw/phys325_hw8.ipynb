# %% [markdown]
# # Due Friday November 7, 2025 (11:59 pm)

# %% [markdown]
# # Problem 1: Model fitting (15 points, 3 points for each part)
# Consider this small data set

# %%
## Run this
import numpy as np
x = np.array([-0.34450244, -0.27538229, -0.20626214, -0.13714199, -0.06802183, 0.00109832,  0.07021847,  0.13933862,  0.20845877,  0.27757892])
y = np.array([0.02893512, 0.05787024, 0.56423488, 1.34548316, 3.24073364, 3.73263071, 3.19733096, 1.67823706, 0.44849439, 0.17361073])

# %% [markdown]
# (a) Plot the data set (x,y) use circle markers.

# %% [markdown]
# (b) Now let's fit this data set to a normal (Gaussian) distribution.  The normal distribution is given by
# $$
# f(x | \mu, \sigma) = \frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{1}{2}(\frac{x - \mu}{\sigma})^2}
# $$
# Greek symbols:  $\mu$: mu. $\sigma$: sigma.
#
# Code up a function `f(x, mu, sigma)` that returns the value of the normal distribution.

# %% [markdown]
# (c) Plot x $\in [-1,1]$, for $\mu=0$ and $\sigma=0.1, 0.2, 0.3$.  Add legend.  Over-plot the data points.
# Does one of the models look like a good description of the data?

# %% [markdown]
# (d) $\chi^2$ (chi-squared) describes the sum of the residuals of the model fitting.
# \begin{equation}
# \chi^2 = \sum_i  \frac{(y_i - f(x_i| \mu, \sigma))^2}{\Delta y^2}
# \end{equation}
#
# Code up a function `chi_squared(sigma)` that takes in $\sigma$ and returns the $\chi^2$ value
# (assuming $\mu=0$, and $\Delta y = 1$).

# %% [markdown]
# (e) Find the $\sigma$ value that minimizes this $\chi^2$.

# %% [markdown]
# # Problem 2: Maximizing a function (10 points)
#
# The efficiency of an incandescent light bulb depends on the temperature and is given by
# \begin{equation}
# \eta = \frac{15}{\pi^4}\int_{hc/(\lambda_2 k_B T)}
# ^{hc/(\lambda_1 k_B T)}
# \frac{x^3}{e^x - 1} dx
# \end{equation}
# Greek letter: $\eta$: eta
# $\lambda_1$ = 390 nm
# $\lambda_2$ = 750 nm
#
# (a) Plot $\eta$ as a function of $T$. Try a few range of $T$ so that we can see the peak of $\eta$.  (5 points)

# %% [markdown]
# (b) Find the temperature where $\eta$ is the highest.
# Please use `np.argmax`
# (5 points)
