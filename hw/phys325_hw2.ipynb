# %% [markdown]
# # Due Friday September 12, 2025 (11:59 pm)

# %% [markdown]
# # Problem 1: Black-body radiation (15 points)

# %% [markdown]
# The Planck function for black-body radiation is given by
# \begin{equation}
# B(\nu) = \frac{2 h \nu^3}{c^2} \frac{1}{e^{h \nu / k_B T} - 1}
# \end{equation}
#
# where
#
# $h = 6.626 \times 10^{-34} \ \rm J \cdot s $
#
# $c = 2.999 \times 10^8 \ \rm m/s $
#
# $k_B = 1.381 \times 10^{-23} \ \rm J/K$

# %% [markdown]
# (a) Create an array called `nu_arr` that ranges from $10^9$ to $10^{12}$, with 1000 equally spaced intervals.
#
# Hint: use `np.linspace`  (2 points)

# %% [markdown]
# (b) For T = 3 K, evaluate $B_\nu$ at nu_arr.
#
# Plot the the function B vs. nu.  (3 points)

# %% [markdown]
# (c) What is the frequency at the peak of the black-body spectrum?
#
# Hint: use  `np.argmax`.  (2 points)

# %% [markdown]
# (d) From Wien's displacement law, we know that the peak wavelength of a black-body radiation is given by
#
# $\nu_{\rm peak} = {5.879 \times 10^{10}}{T}$
#
#
# Use this formula to calculate the peak frequency at $T = 3$ Kelvin.
#
# Is it consistent with your numerical result?  (2 points)

# %% [markdown]
# (e) Write a function with two arguments: `T` and `nu_arr`.  This function plots B vs. nu and calculate the peak frequency. (2 points)

# %% [markdown]
# (f) Plot B vs. nu for 310 K (human body).  Try different range of nu to show the peak of the black-body. What is the peak frequency?
# (2 points)

# %% [markdown]
# (g) Plot B vs. nu 6000 K (the Sun).  Similarly, try different ranges of nu to show the peak. What is the peak frequency?  (2 points)

# %% [markdown]
# # Problem 2:  (15 points)
#
# (a,b,c are 2 points each; d,e,f are 3 points each)
#
# A quantum dot system can be modeled by an electron in an infinite square potential well.
# The energy levels of an electron in an infinite square potential well is given by
# \begin{equation}
# E_n=\frac{n^2\hbar^2\pi^2}{2 m_e L^2},
# \end{equation}
#
# where $m_e$ is the electron mass, $\hbar$ is the reduced Planck constant, $L$ is the width of the well, and $n$ is the quantum number for the energy level (1, 2, 3, $\ldots$).
#
#
# $m_e = 9.11\times 10^{-31} \ \rm kg$
#
# $h = 6.626\times 10^{-34}  \ \rm J \cdot s$
#
# $\hbar = \frac{h}{2\pi} \ \rm J \cdot s$

# %% [markdown]
# (a)
# For $L= 10^{-9} \ \rm m$, print out the energy levels $E_n$ for $n =1, 2, \cdots, 5$.  Avoid for-loop.  (2 points)

# %% [markdown]
# (b)
# When the electron transits from $n_i$ (initial state) to $n_f$ (final state), a photon will be emitted and carries the energy difference between the two levels.
#
# Print the energy difference between $n_i=2,3,4,5$ and $n_f=1$.    (2 points)

# %% [markdown]
# (c) Convert these photon energy values to frequencies, and then convert to wavelengths (in nm).
#
# Hint: $E = h \nu$, $\lambda = c / \nu$
#
# Hint: `lambda` is a reserved word in Python.  Call wavelength something else.
#
# Are these wavelengths visible (380-700 nm)?  (2 points)

# %% [markdown]
# (d) Let's focus on $n_i = 2$ to $n_f = 1$, as it is the most commonly used.
#
# Define a function with argument $L$ and returns the photon's wavelength associated with $n_i = 2$ to $n_f = 1$ transition.   (3 points)

# %% [markdown]
# (e) Plot the photon's wavelength vs. $L$.  $L$ is an array spanning $10^{-10}$ to $10^{-9}$ with 100 elements.
#
# Hint: use `np.linspace`  (3 points)

# %% [markdown]
# (f) What is the range of $L$ that can produce visible photons?
# Hint: use array filtering (3 points)

# %% [markdown]
# We can create photons of different color by changing the size the quantum well!
# Google "quantum dot display" to learn more.
