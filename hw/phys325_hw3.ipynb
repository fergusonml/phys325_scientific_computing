# %% [markdown]
# # Due Thursday September 19, 2025 (11:59 pm)

# %%
# run this first
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First, save this file to your computer:
# https://drive.google.com/file/d/1CIp9ILN4Df4LuGe5UjLT8ppWQQ5y8lCx/view?usp=drive_link

# %%
# then do these steps
from google.colab import files
uploaded = files.upload()
# it will ask you to select a file from your computer

# %% [markdown]
# # Problem: COVID-19 in US and in Idaho, Washington, and Oregon (30 points)
# Please label all the axes and put legends in all figures.
#
# The file `covid_us_id_wa_or_2023.txt` includes the COVID-19 number of cases in the US, Idaho, Washington, and Oregon between Jan 22, 2020 and Mar 9, 2023. Please see the header of the file.
#
# Let's use these numbers
# * US population: 328.2 million
# * Idaho population: 1.787 million
# * Washington population: 7.615 million
# * Oregon population: 4.218 million

# %% [markdown]
# (a) Python has a package called `datetime`.  For example, you can calculate n days after 1/22/2020 by doing this
# ```
# import datetime
# first_day_of_data = datetime.datetime(2020, 1, 22)
# print(first_day_of_data + datetime.timedelta(n))
# ```
# As a practice, print the date of 14 days after 1/22/2020.  (2 points)

# %% [markdown]
# (b) Read in the data using `loadtxt`.  Plot the number of cases for Idaho, Washington, and Oregon. Put them on the same plot and add a legend.
# Use `plt.yscale('log')` to make the y-axis logarithmic.
# (2 points)

# %% [markdown]
# (c) When comparing populations of different sizes, it is customary to calculate the number of cases per 100,000 people. Plot the number of cases per 100,000 vs day for the US, Idaho, Washington, and Oregon. Put them on the same plot and add a legend. (3 points)

# %% [markdown]
# (d) On which day does Idaho get the first case? (Hint: use array filtering) How about Washington and Oregon? Print out these dates using `datetime`.  (3 points)

# %% [markdown]
# (e) Plot the fraction of US cases that are in Idaho, Washington, and Oregon (3 states combined) vs. day.
# Add a horizontal line indicating the fraction of the US population that are in these 3 states.
# Please show the y-axis in log scale. (3 points)

# %% [markdown]
# (f) Calculate the daily **new** cases per 100,000 people vs. day for the US, Idaho, Washington, and Oregon.  Plot all four curves together & add legend. (3 points)

# %% [markdown]
# (g) Define a function that takes in two arrays: day, new_cases, calculates the 7-day running average (similar to the exercise in the lab), and returns `day_7day, mean_7day`.  Please make sure that the two returned arrays have the same length. (3points)

# %% [markdown]
# (h) Plot the 7-day average of the new cases per 100,000 vs. day, for US, Idaho, Washington, and Oregon. (3 points)

# %% [markdown]
# (i) On which day does the US has the highest 7-day average?  How about Idaho, Washington, and Oregon?   Use `datetime` for your answer (2 points)

# %% [markdown]
# (j) For Idaho, plot the day with the highest 7-day average as a vertical line, together with the 7-day average per 100,000, on the same plot. (2 points)

# %% [markdown]
# (k) For Idaho, how many days do we have (7-day average) more than 25 cases per 100,1000 (considered critical)?
# How about the US? (2 points)

# %% [markdown]
# (l) Use words, describe what you've observed about COVID-19 in US, Idaho, Washington, and Oregon from this exercise. (2 points)
