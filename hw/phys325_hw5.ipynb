# %% [markdown]
# # Due Friday October 10, 2025 (11:59 pm)

# %% [markdown]
# #Problem 1: Heat capacity of a solid
#
# Debye's theory of solids gives the heat capacity of a solid at
# temperature $T$ to be
#
# \begin{equation}
# C_V = 9V\rho k_B \biggl( {T\over\theta_D} \biggr)^3 \int_0^{\theta_D/T}
#       {x^4 e^x\over(e^x-1)^2}\> d x,
# \end{equation}
#
# where $V$ is the volume of the solid, $\rho$ is the number density of
# atoms, $k_B$ is Boltzmann's constant, and $\theta_D$ is the so-called
# *Debye temperature*, a property of solids that depends on their
# density and speed of sound.
#
# (a) Write a Python function `cv(T)` that calculates $C_V$ for a given value of the temperature, for a sample consisting of 1000 cubic centimeters of solid aluminum, which has a number density of $\rho=6.022\times 10^{28}\,\mathrm{m}^{-3}$ and a Debye temperature of $\theta_D=428\,$K.  Use `scipy.integrate.quad` to evaluate the integral.  (4 points)

# %% [markdown]
# (b) Use your function to make a graph of the heat capacity as a function of temperature from $T=5\,$K to $T=500\,$K, **logarithmically** spaced (use `np.logspace`). In the plot, use logarithmic scales for both x and y axes.
#
# Hint: You can use
# `plt.loglog(x, y)` or
# `plt.xscale('log')` and
# `plt.yscale('log')`
#
# (4 points)

# %% [markdown]
# (c) Describe in words how heat capacity scales with temperature differently at low temperature vs at high temperature.  (2 points)

# %% [markdown]
# If you're interested in Debye's theory of capacity, check out this Wikipedia page:
# https://en.wikipedia.org/wiki/Debye_model

# %% [markdown]
# # Problem 2: Simple pendulum with a large oscillation angle
# ![Screen Shot 2020-10-01 at 9.30.02 PM.png](data:image/png;base64,...)

# %% [markdown]
# For a simple pendulum with a large oscillation angle, the period is no longer independent of the amplitude.  Let us assume that the pendulum is suspended by a massless rod of length $L$ = 1 m.  The pendulum is released at an angle $\theta_0$.
#
# The period is given by
#
# \begin{equation}
# T = 4\sqrt{\frac{L}{g}} \int_0^{\pi/2}\frac{1}{\sqrt{1-k^2 \sin^2\varphi}} d\varphi
# \end{equation}
#
# where
#
# \begin{equation}
# k = \sin\frac{\theta_0}{2}
# \end{equation}
#
# Note: $\varphi$ is spelled as phi.
#
# (a) Write a function `T(theta_0)` that returns the priod of the pendulum.  Use `scipy.integrate.quad` to evalate the integral.  (4 points)

# %% [markdown]
# (b) Plot T vs. $\theta$ from $\theta$ = 0 to  $\theta = \frac{\pi}{2}$.  (4 points)

# %% [markdown]
# (c) For small $\theta_0$, we know that the period is given by $T=2\pi\sqrt{\frac{L}{g}}$.  Add a horizontal line of this $T$ value.  Is this consistent with your numerical calculation?  (2 points)

# %% [markdown]
# # Problem 3: The Stefan-Boltzmann constant
#
# The Planck theory of thermal radiation tells us that in the (angular) frequency interval $\omega$ to $\omega+d\omega$, a black body of unit area radiates electromagnetically an amount of thermal energy per
# second equal to $I(\omega)\>d\omega$, where
#
# \begin{equation}
# I(\omega) = {\hbar\over4\pi^2c^2}\,{\omega^3\over(e^{\hbar\omega/k_BT}-1)}.
# \end{equation}
#
# Here $\hbar$ is Planck's constant over $2\pi$, $c$ is the speed of light, and $k_B$ is Boltzmann's constant.
#
# If we set $x = \hbar\omega/k_BT$ and integrate $x$ from 0 to infinity, we can get the total energy per unit area radiated by a black body, which is given by
#
# \begin{equation}
# W = {k_B^4 T^4\over4\pi^2c^2\hbar^3} \int_0^\infty {\frac{x^3}{e^x-1}}\>d x.
# \end{equation}
#
# (a) Plot the integrand $f(x) = \frac{x^3}{e^x-1}$.  Adjust the range of x to show the peak of this function.   Although this integral's upper limit is infinity, we don't really need to go that far.  Based on this figure, what is a reasonable numerical upper limit?
# (3 pt)

# %% [markdown]
# (a) Evaluate
# $$
# \int_0^{\infty} \frac{x^3}{e^x - 1}dx
# $$
# using the trapezoidal method.
# Estimate your numerical error using the formula $\epsilon = \frac{1}{3}(I_2 - I_1)$.
#  (4 points)

# %% [markdown]
# (b) Even before Planck gave his theory of thermal radiation around the turn of the 20th century, it was known that the total energy $W$ given off by a black body per unit area per second followed Stefan's law: $W = \sigma T^4$, where $\sigma$ is the Stefan-Boltzmann constant.  Use your value for the integral above to compute a value for the Stefan-Boltzmann constant (in SI units) to three significant figures.  You can use these physical constants.
#
# $c = 2.9979 \times 10^8 \ \rm m/s $
#
# $k_B = 1.381 \times 10^{-23} \ \rm J/K$
#
# $h = 6.626\times 10^{-34}  \ \rm J \cdot s$
#
# $\hbar = \frac{h}{2\pi} \ \rm J \cdot s$
#
# The known value of the Stefan-Boltzmann constant is $5.67\times 10^{-8} W m^{-2} K^4$.  Do you get the same answer?
#
# (3 points)
